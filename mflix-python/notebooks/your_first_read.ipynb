# %%
import pymongo
uri = "mongodb+srv://m220student2:m220password@mflix-xjwqd.mongodb.net/test"
client = pymongo.MongoClient(uri)
mflix = client.mflix
movies = mflix.movies

# %%
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4132'),
#  'title': 'Carmencita',
#  'year': 1894,
#  'runtime': 1,
#  'cast': ['Carmencita'],
#  'poster': 'http://ia.media-imdb.com/images/M/MV5BMjAzNDEwMzk3OV5BMl5BanBnXkFtZTcwOTk4OTM5Ng@@._V1_SX300.jpg',
#  'plot': 'Performing on what looks like a small wooden stage, wearing a dress with a hoop skirt and white high-heeled pumps, Carmencita does a dance with kicks and twirls, a smile always on her face.',
#  'fullplot': 'Performing on what looks like a small wooden stage, wearing a dress with a hoop skirt and white high-heeled pumps, Carmencita does a dance with kicks and twirls, a smile always on her face.',
#  'lastupdated': '2015-08-26 00:03:45.040000000',
#  'type': 'movie',
#  'directors': ['William K.L. Dickson'],
#  'imdb': {'rating': 5.9, 'votes': 1032, 'id': 1},
#  'countries': ['USA'],
#  'rated': 'NOT RATED',
#  'genres': ['Documentary', 'Short']}

# %%
movies.find_one( { "cast": "Salma Hayek" } )
# Out:
# {'_id': ObjectId('573a1399f29313caabceea6d'),
#  'title': 'Roadracers',
#  'year': 1994,
#  'runtime': 95,
#  'released': datetime.datetime(1994, 7, 22, 0, 0),
#  'cast': ['David Arquette', 'John Hawkes', 'Salma Hayek', 'Jason Wiles'],
#  'poster': 'http://ia.media-imdb.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SX300.jpg',
#  'plot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'fullplot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'awards': '1 nomination.',
#  'lastupdated': '2015-09-01 00:53:54.567000000',
#  'type': 'movie',
#  'languages': ['English'],
#  'directors': ['Robert Rodriguez'],
#  'writers': ['Robert Rodriguez', 'Tommy Nix'],
#  'imdb': {'rating': 6.7, 'votes': 2036, 'id': 111002},
#  'countries': ['USA'],
#  'rated': 'R',
#  'genres': ['Action', 'Drama'],
# ...

# %%
movies.find( { "cast": "Salma Hayek" } )

# %%
movies.find( { "cast": "Salma Hayek" } ).count()
# Out:
# c:\source\m220p\mflix-python\activate\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 29

# %%
cursor = movies.find( { "cast": "Salma Hayek" } )
from bson.json_util import dumps
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "title": "Roadracers",
#     "year": 1994,
#     "runtime": 95,
#     "released": {
#       "$date": 774835200000
#     },
#     "cast": [
#       "David Arquette",
#       "John Hawkes",
#       "Salma Hayek",
#       "Jason Wiles"
#     ],
#     "poster": "http://ia.media-imdb.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SX300.jpg",
#     "plot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "fullplot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "awards": "1 nomination.",
#     "lastupdated": "2015-09-01 00:53:54.567000000",
#     "type": "movie",
#     "languages": [
#       "English"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "writers": [
#       "Robert Rodriguez",
# ...

# %%
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1 } )
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "title": "Roadracers"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef0b6"
#     },
#     "title": "Midaq Alley"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef179"
#     },
#     "title": "Desperado"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf07cf"
#     },
#     "title": "Breaking Up"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf092d"
#     },
#     "title": "Fools Rush In"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf09f1"
#     },
#     "title": "The Hunchback"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e4f"
#     },
#     "title": 54
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0ea6"
#     },
#     "title": "Frida"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f3b"
#     },
#     "title": "The Velocity of Gary"
#   },
#   {
#     "_id": {
# ...

# %%
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1, "_id": 0 } )
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "title": "Roadracers"
#   },
#   {
#     "title": "Midaq Alley"
#   },
#   {
#     "title": "Desperado"
#   },
#   {
#     "title": "Breaking Up"
#   },
#   {
#     "title": "Fools Rush In"
#   },
#   {
#     "title": "The Hunchback"
#   },
#   {
#     "title": 54
#   },
#   {
#     "title": "Frida"
#   },
#   {
#     "title": "The Velocity of Gary"
#   },
#   {
#     "title": "Wild Wild West"
#   },
#   {
#     "title": "No One Writes to the Colonel"
#   },
#   {
#     "title": 54
#   },
#   {
#     "title": "Chain of Fools"
#   },
#   {
#     "title": "In the Time of the Butterflies"
#   },
#   {
#     "title": "Once Upon a Time in Mexico"
#   },
#   {
#     "title": "After the Sunset"
#   },
#   {
#     "title": "Ask the Dust"
#   },
#   {
#     "title": "Bandidas"
#   },
#   {
#     "title": "Lonely Hearts"
#   },
#   {
#     "title": "Puss in Boots"
#   },
#   {
#     "title": "The Prophet"
#   },
#   {
#     "title": "Here Comes the Boom"
#   },
#   {
# ...

# %%
cursor = movies.find( { "countries": "Kosovo" }, { "title": 1, "_id": 1, "genres": 1 } )
list(cursor)
#print(dumps(cursor, indent=2))
# Out:
# [{'_id': ObjectId('573a13eff29313caabdd7dca'),
#   'title': 'Sworn Virgin',
#   'genres': ['Drama']},
#  {'_id': ObjectId('573a13faf29313caabdec74f'),
#   'title': 'Babai',
#   'genres': ['Drama']}]

# %%
cursor = movies.findOne( { "countries": { "$in": ['Russia', 'Japan'] } }, { "title": 1, "_id": 1, "genre": 1 } )
len(cursor)
#print(dumps(cursor, indent=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3401434f9d28> in <module>
# ----> 1 cursor = movies.findOne( { "countries": { "$in": ['Russia', 'Japan'] } }, { "title": 1, "_id": 1, "genre": 1 } )
#       2 len(cursor)
#       3 #print(dumps(cursor, indent=2))
#
# c:\source\m220p\mflix-python\activate\lib\site-packages\pymongo\collection.py in __call__(self, *args, **kwargs)
#    3319                         "call the '%s' method on a 'Collection' object it is "
#    3320                         "failing because no such method exists." %
# -> 3321                         self.__name.split(".")[-1])
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'findOne' method on a 'Collection' object it is failing because no such method exists.
